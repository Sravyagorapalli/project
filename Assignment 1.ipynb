# %%
#question 1
RAINBOW

# %%
#question 2
print("LETS UPGRADE")
# Out:
# LETS UPGRADE

# %%
#question 3
cp1=20
sp1=30
print(cp1)
print(sp1)
if sp1>cp1:
    print("profit")
elif sp1<cp1n:
    print("loss")
else:
    print("neither")
cp2=20
sp2=10
print(cp2)
print(sp2)
if sp2>cp2:
    print("profit")
elif sp2<cp2:
    print("loss")
else:
    print("neither")
cp3=20
sp3=20
print(cp3)
print(sp3)
if sp3>cp3:
    print("profit")
elif sp3<cp3:
    print("loss")
else:
    print("neither")
cp4=19
sp4=19
print(cp4)
print(sp4)
if sp4>cp4:
    print("profit")
elif sp4<cp4:
    print("loss")
else:
    print("neither")
cp5=23
sp5=7
print(cp5)
print(sp5)
if sp5>cp5:
    print("profit")
elif sp5<cp5:
    print("loss")
else:
    print("neither")
cp6=19
sp6=95
print(cp6)
print(sp6)
if sp6>cp6:
    print("profit")
elif sp6<cp6:
    print("loss")
else:
    print("neither")
# Out:
# 20
# 30
# profit
# 20
# 10
# loss
# 20
# 20
# neither
# 19
# 19
# neither
# 23
# 7
# loss
# 19
# 95
# profit

# %%
#question 4
#one euro=Rs.80 
#consider one euro as euro
euro=80
euro1=20
print(euro1)
rs1=euro1*euro
print(rs1)
euro2=50
print(euro2)
rs2=euro2*euro
print(rs2)
euro3=72
print(euro3)
rs3=euro3*euro
print(rs3)
euro4=7
print(euro4)
rs4=euro4*euro
print(rs4)
euro5=35
print(euro5)
rs5=euro5*euro
print(rs5)
euro6=23
print(euro6)
rs6=euro6*euro
print(rs6)
euro7=95
print(euro7)
rs7=euro7*euro
print(rs7)
euro8=18
print(euro8)
rs8=euro8*euro
print(rs8)
# Out:
# 20
# 1600
# 50
# 4000
# 72
# 5760
# 7
# 560
# 35
# 2800
# 23
# 1840
# 95
# 7600
# 18
# 1440
